# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.calibration import LabelEncoder
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import json
import pickle
import re

# %% [markdown]
# Data Importing and loading

# %%
df_1=pd.read_csv('D:/project/.venv/sigapore_flat/Resale Date19901999.csv')
df_2=pd.read_csv('D:/project/.venv/sigapore_flat/ResaleDate2000Feb2012.csv')
df_3=pd.read_csv('D:/project/.venv/sigapore_flat/ResaleDateFromJan2015toDec2016.csv')
df_4=pd.read_csv('D:/project/.venv/sigapore_flat/ResaledatefromJan2017onwards.csv')
df_5=pd.read_csv('D:/project/.venv/sigapore_flat/ResaleDateFromMar2012toDec2014.csv')

# %%
df=pd.concat([df_1,df_2,df_3,df_4,df_5],axis=0)
df.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# Exploratory Data analysis

# %%
df.shape
# Out:
# (929985, 11)

# %%
df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 929985 entries, 0 to 52202
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                929985 non-null  object
#  1   town                 929985 non-null  object
#  2   flat_type            929985 non-null  object
#  3   block                929985 non-null  object
#  4   street_name          929985 non-null  object
#  5   storey_range         929985 non-null  object
#  6   floor_area_sqm       929985 non-null  float64
#  7   flat_model           929985 non-null  object
#  8   lease_commence_date  929985 non-null  int64
#  9   resale_price         929985 non-null  float64
#  10  remaining_lease      220935 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 85.1+ MB

# %%
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df.drop(columns=["remaining_lease"],inplace=True)

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
df['month'].unique()
# Out:
# array(['1990-01', '1990-02', '1990-03', '1990-04', '1990-05', '1990-06',
#        '1990-07', '1990-08', '1990-09', '1990-10', '1990-11', '1990-12',
#        '1991-01', '1991-02', '1991-03', '1991-04', '1991-05', '1991-06',
#        '1991-07', '1991-08', '1991-09', '1991-10', '1991-11', '1991-12',
#        '1992-01', '1992-02', '1992-03', '1992-04', '1992-05', '1992-06',
#        '1992-07', '1992-08', '1992-09', '1992-10', '1992-11', '1992-12',
#        '1993-01', '1993-02', '1993-03', '1993-04', '1993-05', '1993-06',
#        '1993-07', '1993-08', '1993-09', '1993-10', '1993-11', '1993-12',
#        '1994-01', '1994-02', '1994-03', '1994-04', '1994-05', '1994-06',
#        '1994-07', '1994-08', '1994-09', '1994-10', '1994-11', '1994-12',
#        '1995-01', '1995-02', '1995-03', '1995-04', '1995-05', '1995-06',
#        '1995-07', '1995-08', '1995-09', '1995-10', '1995-11', '1995-12',
#        '1996-01', '1996-02', '1996-03', '1996-04', '1996-05', '1996-06',
#        '1996-07', '1996-08', '1996-09', '1996-10', '1996-11', '1996-12',
#        '1997-01', '1997-02', '1997-03', '1997-04', '1997-05', '1997-06',
#        '1997-07', '1997-08', '1997-09', '1997-10', '1997-11', '1997-12',
#        '1998-01', '1998-02', '1998-03', '1998-04', '1998-05', '1998-06',
#        '1998-07', '1998-08', '1998-09', '1998-10', '1998-11', '1998-12',
#        '1999-01', '1999-02', '1999-03', '1999-04', '1999-05', '1999-06',
#        '1999-07', '1999-08', '1999-09', '1999-10', '1999-11', '1999-12',
#        '2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06',
#        '2000-07', '2000-08', '2000-09', '2000-10', '2000-11', '2000-12',
#        '2001-01', '2001-02', '2001-03', '2001-04', '2001-05', '2001-06',
#        '2001-07', '2001-08', '2001-09', '2001-10', '2001-11', '2001-12',
#        '2002-01', '2002-02', '2002-03', '2002-04', '2002-05', '2002-06',
#        '2002-07', '2002-08', '2002-09', '2002-10', '2002-11', '2002-12',
#        '2003-01', '2003-02', '2003-03', '2003-04', '2003-05', '2003-06',
#        '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12',
#        '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06',
#        '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12',
#        '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06',
#        '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12',
#        '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06',
#        '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12',
#        '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06',
#        '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12',
#        '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
#        '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12',
#        '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#        '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12',
#        '2012-01', '2012-02', '2015-01', '2015-02', '2015-03', '2015-04',
#        '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10',
#        '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04',
#        '2016-05', '2016-06', '2016-07', '2016-08', '2016-09', '2016-10',
#        '2016-11', '2016-12', '2017-01', '2017-02', '2017-03', '2017-04',
#        '2017-05', '2017-06', '2017-07', '2017-08', '2017-09', '2017-10',
#        '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04',
#        '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10',
#        '2018-11', '2018-12', '2019-01', '2019-02', '2019-03', '2019-04',
#        '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10',
#        '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04',
#        '2020-05', '2020-06', '2020-07', '2020-08', '2020-09', '2020-10',
#        '2020-11', '2020-12', '2021-01', '2021-02', '2021-03', '2021-04',
#        '2021-05', '2021-06', '2021-07', '2021-08', '2021-09', '2021-10',
#        '2021-11', '2021-12', '2022-01', '2022-02', '2022-03', '2022-04',
#        '2022-05', '2022-06', '2022-07', '2022-08', '2022-09', '2022-10',
#        '2022-11', '2022-12', '2023-01', '2023-02', '2023-03', '2023-04',
#        '2023-05', '2023-06', '2023-07', '2023-08', '2023-09', '2023-10',
#        '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04',
#        '2024-05', '2024-06', '2024-07', '2012-03', '2012-04', '2012-05',
#        '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11',
#        '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05',
#        '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11',
#        '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05',
#        '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11',
#        '2014-12'], dtype=object)

# %%
df.loc[:,'reg_year']=df['month'].apply(lambda x:int(x.split('-')[0]))
df.loc[:,'reg_month']=df['month'].apply(lambda x:int(x.split('-')[1]))

# %%
df.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#    reg_year  reg_month
# 0      1990          1
# 1      1990          1
# 2      1990          1
# 3      1990          1
# 4      1990          1

# %%
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df.loc[df['flat_type']=='MULTI-GENERATION','flat_type']='MULTI GENERATION'
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION'], dtype=object)

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'reg_year', 'reg_month'],
#       dtype='object')

# %%
df['town'].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
df['block'].unique()
# Out:
# array(['309', '216', '211', ..., '240A', '460D', '83A'], dtype=object)

# %%
df.loc[:,'block']=df['block'].astype(str)
df.loc[:,'block']=df['block'].apply(lambda x: ''.join(y for y in x if y in '0123456789'))

# %%
df['block'].unique()
# Out:
# array(['309', '216', '211', '202', '235', '232', '308', '220', '219',
#        '247', '320', '252', '223', '230', '329', '313', '117', '110',
#        '343', '345', '346', '121', '129', '130', '128', '127', '126',
#        '403', '404', '405', '417', '418', '419', '441', '442', '443',
#        '444', '450', '435', '433', '434', '424', '425', '466', '471',
#        '474', '570', '586', '455', '465', '463', '564', '560', '558',
#        '559', '538', '534', '601', '603', '604', '608', '611', '505',
#        '503', '610', '607', '524', '513', '643', '542', '548', '550',
#        '639', '637', '330', '333', '156', '152', '178', '180', '209',
#        '231', '254', '103', '105', '344', '324', '120', '124', '414',
#        '438', '427', '428', '473', '573', '585', '456', '544', '640',
#        '638', '646', '150', '179', '336', '335', '401', '439', '430',
#        '460', '459', '716', '545', '620', '622', '259', '101', '18', '28',
#        '29', '30', '75', '76', '501', '502', '504', '2', '20', '21', '59',
#        '58', '55', '22', '104', '107', '69', '33', '46', '116', '115',
#        '125', '138', '87', '100', '412', '402', '416', '136', '529',
#        '510', '525', '218', '213', '532', '533', '536', '537', '44',
#        '540', '702', '615', '712', '50', '54', '606', '616', '15', '34',
#        '36', '35', '41', '42', '53', '51', '8', '718', '724', '166', '71',
#        '82', '78', '79', '80', '134', '132', '131', '133', '89', '62',
#        '422', '507', '508', '517', '95', '93', '43', '543', '547', '708',
#        '707', '713', '609', '61', '56', '165', '710', '613', '602', '605',
#        '112', '1', '722', '72', '31', '111', '118', '96', '137', '139',
#        '725', '24', '304', '310', '160', '161', '164', '177', '205',
#        '248', '258', '4', '6', '146', '143', '145', '182', '228', '227',
#        '244', '113', '163', '169', '204', '135', '184', '225', '123',
#        '307', '221', '214', '142', '140', '141', '7', '40', '77', '119',
#        '114', '5', '12', '16', '13', '108', '102', '106', '63', '60', '3',
#        '19', '26', '37', '47', '109', '57', '48', '73', '66', '264',
#        '271', '664', '9', '10', '663', '662', '632', '633', '642', '440',
#        '509', '363', '365', '334', '323', '322', '326', '314', '312',
#        '354', '506', '305', '306', '303', '431', '339', '515', '520',
#        '703', '704', '711', '705', '731', '728', '706', '411', '315',
#        '311', '301', '729', '371', '415', '413', '337', '717', '723',
#        '201', '81', '45', '85', '98', '99', '65', '23', '67', '49', '39',
#        '38', '17', '319', '318', '327', '410', '239', '154', '341', '352',
#        '251', '302', '234', '237', '233', '242', '243', '257', '210',
#        '208', '316', '408', '240', '331', '406', '167', '168', '170',
#        '172', '185', '186', '187', '212', '215', '516', '511', '457',
#        '490', '489', '487', '485', '476', '477', '527', '535', '484',
#        '491', '481', '217', '448', '446', '447', '554', '551', '458',
#        '436', '452', '539', '198', '203', '407', '469', '468', '801',
#        '97', '11', '68', '94', '14', '84', '83', '52', '807', '461', '32',
#        '171', '173', '88', '86', '74', '25', '267', '269', '924', '925',
#        '817', '818', '808', '809', '285', '287', '274', '291', '293',
#        '262', '914', '250', '226', '236', '270', '420', '157', '820',
#        '819', '813', '810', '266', '265', '286', '272', '275', '295',
#        '261', '913', '910', '253', '277', '928', '832', '838', '839',
#        '159', '812', '811', '294', '432', '816', '289', '298', '912',
#        '278', '279', '245', '149', '148', '91', '27', '206', '193', '200',
#        '162', '701', '736', '742', '276', '751', '752', '733', '740',
#        '280', '772', '229', '238', '255', '256', '328', '348', '571',
#        '584', '454', '575', '561', '512', '523', '644', '621', '625',
#        '155', '470', '565', '546', '612', '648', '70', '122', '426',
#        '530', '519', '526', '626', '709', '719', '207', '175', '249',
#        '260', '183', '641', '362', '409', '429', '518', '449', '379',
#        '359', '347', '342', '340', '846', '317', '321', '325', '357',
#        '241', '462', '475', '528', '480', '514', '437', '451', '486',
#        '199', '64', '153', '90', '224', '814', '283', '297', '848', '831',
#        '281', '273', '916', '902', '921', '934', '268', '805', '833',
#        '804', '903', '932', '151', '147', '174', '195', '222', '741',
#        '756', '390', '737', '726', '358', '421', '445', '587', '464',
#        '557', '549', '624', '631', '572', '563', '552', '522', '614',
#        '715', '714', '144', '661', '634', '730', '338', '349', '351',
#        '353', '246', '521', '488', '478', '555', '556', '907', '282',
#        '292', '935', '263', '933', '926', '922', '191', '732', '158',
#        '727', '721', '284', '759', '858', '576', '578', '541', '623',
#        '332', '423', '176', '181', '668', '364', '374', '350', '373',
#        '381', '355', '531', '483', '553', '909', '930', '915', '911',
#        '931', '815', '194', '754', '749', '618', '92', '628', '472',
#        '806', '837', '290', '296', '857', '735', '746', '649', '635',
#        '636', '367', '360', '376', '854', '288', '747', '738', '768',
#        '757', '467', '562', '617', '627', '361', '368', '370', '479',
#        '852', '745', '771', '766', '773', '755', '758', '577', '619',
#        '720', '377', '356', '842', '453', '803', '937', '762', '739',
#        '774', '760', '366', '375', '844', '734', '778', '197', '369',
#        '929', '830', '856', '764', '744', '684', '908', '765', '686',
#        '683', '840', '783', '784', '750', '770', '495', '835', '685',
#        '682', '853', '753', '781', '775', '657', '776', '498', '824',
#        '847', '378', '645', '681', '841', '782', '388', '674', '675',
#        '845', '851', '785', '372', '673', '482', '836', '788', '189',
#        '829', '843', '800', '629', '630', '676', '761', '655', '794',
#        '790', '689', '492', '748', '795', '796', '799', '196', '696',
#        '849', '798', '791', '494', '897', '855', '802', '779', '190',
#        '688', '658', '660', '687', '697', '827', '777', '743', '651',
#        '647', '695', '698', '693', '694', '665', '828', '906', '653',
#        '867', '667', '680', '763', '780', '671', '690', '883', '792',
#        '192', '669', '977', '944', '691', '917', '825', '895', '672',
#        '650', '884', '821', '881', '885', '882', '393', '394', '666',
#        '656', '399', '386', '391', '652', '862', '864', '863', '860',
#        '659', '868', '859', '861', '397', '786', '787', '826', '877',
#        '834', '876', '678', '898', '878', '767', '872', '880', '874',
#        '380', '677', '870', '871', '865', '866', '879', '797', '875',
#        '389', '850', '920', '387', '392', '904', '949', '395', '396',
#        '822', '886', '873', '670', '899', '692', '978', '887', '939',
#        '905', '927', '894', '679', '936', '919', '896', '188', '923',
#        '888', '938', '654', '943', '940', '942', '398', '769', '966',
#        '945', '889', '941', '947', '946', '918', '869', '976', '979',
#        '567', '948', '953', '789', '980', '823', '974', '496', '965',
#        '975', '952', '961', '500', '950', '382', '568', '385', '793',
#        '497', '893', '566', '569', '493', '384', '383', '580', '579',
#        '700', '581', '583', '582', '574', '891', '892', '299', '300',
#        '962', '699', '956', '951', '957', '958', '955', '954', '964',
#        '959', '963', '969', '968', '970', '960', '973', '972', '971',
#        '967', '596', '588', '589', '981', '984', '985', '986', '989',
#        '987', '988', '990', '499', '590', '591', '592', '593', '890',
#        '997', '992', '998', '991', '996', '995', '999'], dtype=object)

# %%
df['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'Type S1', 'Type S2',
#        'DBSS', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
df['floor_area_sqm'].unique()
# Out:
# array([ 31. ,  73. ,  67. ,  82. ,  74. ,  88. ,  89. ,  83. ,  68. ,
#         75. ,  81. ,  91. ,  92. ,  97. ,  90. ,  98. ,  99. , 100. ,
#         93. , 103. , 119. , 120. , 118. , 121. , 135. , 117. ,  45. ,
#         65. ,  59. ,  70. ,  76. ,  84. , 104. , 105. , 125. , 132. ,
#        139. , 123. , 143. , 151. ,  69. , 106. , 107. , 116. , 149. ,
#        141. , 146. , 148. , 145. , 154. , 150. ,  29. ,  51. ,  61. ,
#         63. ,  64. ,  72. ,  58. ,  66. ,  60. ,  53. ,  54. ,  56. ,
#         77. , 133. , 131. , 115. ,  43. ,  38. ,  41. ,  85. , 111. ,
#        101. , 112. , 137. , 127. , 147. , 163. ,  50. ,  40. ,  60.3,
#         62. ,  55. ,  57. ,  52. ,  63.1, 102. ,  83.1, 126. , 140. ,
#        142. ,  71. , 108. , 144. ,  96. , 114. , 157. , 152. , 155. ,
#         87. , 109. , 110. ,  94. , 134. , 122. , 128. ,  78. ,  46. ,
#         42. ,  49. ,  47. ,  86. , 156. ,  79. ,  80. , 124. ,  28. ,
#        113. ,  95. , 160. , 136. ,  48. , 138. , 161. ,  39. , 130. ,
#        159. , 206. ,  68.2,  64.9, 129. , 165. , 153. , 166. , 210. ,
#         59.2,  73.1,  48.1, 174. ,  74.9, 164. , 158. ,  37. , 198. ,
#        173. , 199. , 261. , 179. ,  69.7, 246. , 171. , 181. ,  44. ,
#        169. , 189. ,  67.2, 222. ,  64.8, 250. ,  74.8, 215. , 237. ,
#         59.1, 185. , 297. , 177. , 243. ,  69.9, 162. , 170. , 190. ,
#        175. , 187. , 241. , 186. ,  56.4, 176. ,  75.9, 184. , 178. ,
#         69.2, 172. , 168. , 167. , 152.4,  64.7, 195. , 188. , 225. ,
#        307. , 182. , 131.1, 192. , 183. , 280. , 180. , 221. , 193. ,
#        207. ,  89.1,  88.1, 259. , 266. ,  87.1,  34. ,  35. , 239. ,
#        249. , 100.2, 208. , 189.4,  68.8])

# %%
df['lease_commence_date'].unique()
# Out:
# array([1977, 1976, 1978, 1979, 1984, 1980, 1985, 1981, 1982, 1986, 1972,
#        1983, 1973, 1969, 1975, 1971, 1974, 1967, 1970, 1968, 1988, 1987,
#        1989, 1990, 1992, 1993, 1994, 1991, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 1966, 2002, 2006, 2003, 2005, 2004, 2008, 2007, 2009,
#        2010, 2012, 2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020],
#       dtype=int64)

# %%
df['storey_range'].unique()
# Out:
# array(['10 TO 12', '04 TO 06', '07 TO 09', '01 TO 03', '13 TO 15',
#        '19 TO 21', '16 TO 18', '25 TO 27', '22 TO 24', '28 TO 30',
#        '31 TO 33', '40 TO 42', '37 TO 39', '34 TO 36', '46 TO 48',
#        '43 TO 45', '49 TO 51', '06 TO 10', '01 TO 05', '11 TO 15',
#        '16 TO 20', '21 TO 25', '26 TO 30', '36 TO 40', '31 TO 35'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'reg_year', 'reg_month'],
#       dtype='object')

# %%
df.drop(columns=['month'],inplace=True)

# %%
a=['resale_price','floor_area_sqm']
for i in a:
    sns.distplot(df[i])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\halee\AppData\Local\Temp\ipykernel_13796\800609761.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# C:\Users\halee\AppData\Local\Temp\ipykernel_13796\800609761.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])

# %%
plt.figure(figsize = (9,5))
plt.title('floor area of flat type')
sns.barplot(x = 'flat_type', y ='floor_area_sqm', data = df,)
# Out:
# <Axes: title={'center': 'floor area of flat type'}, xlabel='flat_type', ylabel='floor_area_sqm'>

# %% [markdown]
# Encode the data with label encoder

# %%
Lable_encode=LabelEncoder()
df.loc[:, 'street_name'] = Lable_encode.fit_transform(df['street_name']).astype('int32')

# %%
df.loc[:, 'flat_type'] = Lable_encode.fit_transform(df['flat_type'])

# %%
df.loc[:, 'flat_model'] = Lable_encode.fit_transform(df['flat_model'])

# %%
df.loc[:, 'town'] = Lable_encode.fit_transform(df['town'])

# %%
df.loc[:, 'storey_range'] = Lable_encode.fit_transform(df['storey_range'])

# %%
df
# Out:
#       town flat_type block street_name storey_range  floor_area_sqm  \
# 0        0         0   309          13            5            31.0
# 1        0         0   309          13            2            31.0
# 2        0         0   309          13            5            31.0
# 3        0         0   309          13            4            31.0
# 4        0         2   216          13            2            73.0
# ...    ...       ...   ...         ...          ...             ...
# 52198   26         4   816         575            5           122.0
# 52199   26         5   325         561            5           146.0
# 52200   26         5   618         563            4           164.0
# 52201   26         5   277         567            4           152.0
# 52202   26         5   277         567            2           146.0
#
#       flat_model  lease_commence_date  resale_price  reg_year  reg_month
# 0              7                 1977        9000.0      1990          1
# 1              7                 1977        6000.0      1990          1
# 2              7                 1977        8000.0      1990          1
# 3              7                 1977        6000.0      1990          1
# 4             20                 1976       47200.0      1990          1
# ...          ...                  ...           ...       ...        ...
# 52198          9                 1988      580000.0      2014         12
# 52199         15                 1988      540000.0      2014         12
# 52200          5                 1992      738000.0      2014         12
# 52201         15                 1985      592000.0      2014         12
# 52202         15                 1985      545000.0      2014         12
#
# [929985 rows x 11 columns]

# %%
x=df[['town','flat_type','block','street_name','storey_range','floor_area_sqm','flat_model','lease_commence_date','resale_price']].corr()
plt.figure(figsize = (11,5))
sns.heatmap(x, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# split the data as Feature and target

# %%
x=df[['town','flat_type','block','street_name','storey_range','floor_area_sqm','flat_model','lease_commence_date','reg_year','reg_month']]
y=df[['resale_price']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train , y_train)
y_pred = linear_reg.predict(x_test)
print(f'MAE = {metrics.mean_absolute_error(y_test,y_pred)}')
print(f'MSE = {metrics.mean_squared_error(y_test,y_pred)}')
print(f'R2 Score = {linear_reg.score(x_test,y_test)}')
# Out:
# MAE = 60771.85972513925
# MSE = 6663651914.964264
# R2 Score = 0.773121786597614

# %%
decision_reg = DecisionTreeRegressor()
decision_reg.fit(x_train , y_train)
y_pred = decision_reg.predict(x_test)
print(f'MAE = {metrics.mean_absolute_error(y_test,y_pred)}')
print(f'MSE = {metrics.mean_squared_error(y_test,y_pred)}')
print(f'R2 Score = {decision_reg.score(x_test,y_test)}')
# Out:
# MAE = 19370.411645726253
# MSE = 871153709.0128231
# R2 Score = 0.9703397176770523

# %%
with open ('sell.pkl', 'wb') as f:
    pickle.dump(decision_reg , f)

# %%
cat_column=['town', 'flat_type', 'block', 'street_name', 'flat_model']
unique_dist={}
for i in cat_column:
    unique_dist[f'{i}_initial']=df[i].unique().tolist()

    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    unique_dist[f'{i}_Final']=df[i].unique().tolist()
unique_dist
# Out:
# {'town_initial': [0,
#   1,
#   2,
#   3,
#   4,
#   6,
#   7,
#   8,
#   9,
#   10,
#   11,
#   12,
#   13,
#   14,
#   16,
#   19,
#   21,
#   22,
#   23,
#   24,
#   25,
#   26,
#   15,
#   20,
#   5,
#   17,
#   18],
#  'town_Final': [0,
#   1,
#   2,
#   3,
#   4,
#   6,
#   7,
#   8,
#   9,
#   10,
#   11,
#   12,
#   13,
#   14,
#   16,
#   19,
#   21,
#   22,
#   23,
#   24,
#   25,
#   26,
#   15,
#   20,
#   5,
#   17,
#   18],
#  'flat_type_initial': [0, 2, 3, 4, 1, 5, 6],
#  'flat_type_Final': [0, 2, 3, 4, 1, 5, 6],
#  'block_initial': ['309',
#   '216',
#   '211',
#   '202',
#   '235',
#   '232',
#   '308',
#   '220',
#   '219',
#   '247',
#   '320',
#   '252',
#   '223',
#   '230',
#   '329',
#   '313',
#   '117',
#   '110',
#   '343',
#   '345',
#   '346',
#   '121',
#   '129',
#   '130',
#   '128',
#   '127',
#   '126',
#   '403',
#   '404',
#   '405',
#   '417',
#   '418',
#   '419',
#   '441',
#   '442',
#   '443',
#   '444',
#   '450',
#   '435',
#   '433',
#   '434',
#   '424',
#   '425',
#   '466',
#   '471',
#   '474',
#   '570',
#   '586',
#   '455',
#   '465',
#   '463',
#   '564',
#   '560',
#   '558',
#   '559',
#   '538',
#   '534',
#   '601',
#   '603',
#   '604',
#   '608',
#   '611',
#   '505',
#   '503',
#   '610',
#   '607',
#   '524',
#   '513',
#   '643',
#   '542',
#   '548',
#   '550',
#   '639',
#   '637',
#   '330',
#   '333',
#   '156',
#   '152',
#   '178',
#   '180',
#   '209',
#   '231',
#   '254',
#   '103',
#   '105',
#   '344',
#   '324',
#   '120',
#   '124',
#   '414',
#   '438',
#   '427',
#   '428',
#   '473',
#   '573',
#   '585',
#   '456',
#   '544',
#   '640',
#   '638',
#   '646',
#   '150',
#   '179',
#   '336',
#   '335',
#   '401',
#   '439',
#   '430',
#   '460',
#   '459',
#   '716',
#   '545',
#   '620',
#   '622',
#   '259',
#   '101',
#   '18',
#   '28',
#   '29',
#   '30',
#   '75',
#   '76',
#   '501',
#   '502',
#   '504',
#   '2',
#   '20',
#   '21',
#   '59',
#   '58',
#   '55',
#   '22',
#   '104',
#   '107',
#   '69',
#   '33',
#   '46',
#   '116',
#   '115',
#   '125',
#   '138',
#   '87',
#   '100',
#   '412',
#   '402',
#   '416',
#   '136',
#   '529',
#   '510',
#   '525',
#   '218',
#   '213',
#   '532',
#   '533',
#   '536',
#   '537',
#   '44',
#   '540',
#   '702',
#   '615',
#   '712',
#   '50',
#   '54',
#   '606',
#   '616',
#   '15',
#   '34',
#   '36',
#   '35',
#   '41',
#   '42',
#   '53',
#   '51',
#   '8',
#   '718',
#   '724',
#   '166',
#   '71',
#   '82',
#   '78',
#   '79',
#   '80',
#   '134',
#   '132',
#   '131',
#   '133',
#   '89',
#   '62',
#   '422',
#   '507',
#   '508',
#   '517',
#   '95',
#   '93',
#   '43',
#   '543',
#   '547',
#   '708',
#   '707',
#   '713',
#   '609',
#   '61',
#   '56',
#   '165',
#   '710',
#   '613',
#   '602',
#   '605',
#   '112',
#   '1',
#   '722',
#   '72',
#   '31',
#   '111',
#   '118',
#   '96',
#   '137',
#   '139',
#   '725',
#   '24',
#   '304',
#   '310',
#   '160',
#   '161',
#   '164',
#   '177',
#   '205',
#   '248',
#   '258',
#   '4',
#   '6',
#   '146',
#   '143',
#   '145',
#   '182',
#   '228',
#   '227',
#   '244',
#   '113',
#   '163',
#   '169',
#   '204',
#   '135',
#   '184',
#   '225',
#   '123',
#   '307',
#   '221',
#   '214',
#   '142',
#   '140',
#   '141',
#   '7',
#   '40',
#   '77',
#   '119',
#   '114',
#   '5',
#   '12',
#   '16',
#   '13',
#   '108',
#   '102',
#   '106',
#   '63',
#   '60',
#   '3',
#   '19',
#   '26',
#   '37',
#   '47',
#   '109',
#   '57',
#   '48',
#   '73',
#   '66',
#   '264',
#   '271',
#   '664',
#   '9',
#   '10',
#   '663',
#   '662',
#   '632',
#   '633',
#   '642',
#   '440',
#   '509',
#   '363',
#   '365',
#   '334',
#   '323',
#   '322',
#   '326',
#   '314',
#   '312',
#   '354',
#   '506',
#   '305',
#   '306',
#   '303',
#   '431',
#   '339',
#   '515',
#   '520',
#   '703',
#   '704',
#   '711',
#   '705',
#   '731',
#   '728',
#   '706',
#   '411',
#   '315',
#   '311',
#   '301',
#   '729',
#   '371',
#   '415',
#   '413',
#   '337',
#   '717',
#   '723',
#   '201',
#   '81',
#   '45',
#   '85',
#   '98',
#   '99',
#   '65',
#   '23',
#   '67',
#   '49',
#   '39',
#   '38',
#   '17',
#   '319',
#   '318',
#   '327',
#   '410',
#   '239',
#   '154',
#   '341',
#   '352',
#   '251',
#   '302',
#   '234',
#   '237',
#   '233',
#   '242',
#   '243',
#   '257',
#   '210',
#   '208',
#   '316',
#   '408',
#   '240',
#   '331',
#   '406',
#   '167',
#   '168',
#   '170',
#   '172',
#   '185',
#   '186',
#   '187',
#   '212',
#   '215',
#   '516',
#   '511',
#   '457',
#   '490',
#   '489',
#   '487',
#   '485',
#   '476',
#   '477',
#   '527',
#   '535',
#   '484',
#   '491',
#   '481',
#   '217',
#   '448',
#   '446',
#   '447',
#   '554',
#   '551',
#   '458',
#   '436',
#   '452',
#   '539',
#   '198',
#   '203',
#   '407',
#   '469',
#   '468',
#   '801',
#   '97',
#   '11',
#   '68',
#   '94',
#   '14',
#   '84',
#   '83',
#   '52',
#   '807',
#   '461',
#   '32',
#   '171',
#   '173',
#   '88',
#   '86',
#   '74',
#   '25',
#   '267',
#   '269',
#   '924',
#   '925',
#   '817',
#   '818',
#   '808',
#   '809',
#   '285',
#   '287',
#   '274',
#   '291',
#   '293',
#   '262',
#   '914',
#   '250',
#   '226',
#   '236',
#   '270',
#   '420',
#   '157',
#   '820',
#   '819',
#   '813',
#   '810',
#   '266',
#   '265',
#   '286',
#   '272',
#   '275',
#   '295',
#   '261',
#   '913',
#   '910',
#   '253',
#   '277',
#   '928',
#   '832',
#   '838',
#   '839',
#   '159',
#   '812',
#   '811',
#   '294',
#   '432',
#   '816',
#   '289',
#   '298',
#   '912',
#   '278',
#   '279',
#   '245',
#   '149',
#   '148',
#   '91',
#   '27',
#   '206',
#   '193',
#   '200',
#   '162',
#   '701',
#   '736',
#   '742',
#   '276',
#   '751',
#   '752',
#   '733',
#   '740',
#   '280',
#   '772',
#   '229',
#   '238',
#   '255',
#   '256',
#   '328',
#   '348',
#   '571',
#   '584',
#   '454',
#   '575',
#   '561',
#   '512',
#   '523',
#   '644',
#   '621',
#   '625',
#   '155',
#   '470',
#   '565',
#   '546',
#   '612',
#   '648',
#   '70',
#   '122',
#   '426',
#   '530',
#   '519',
#   '526',
#   '626',
#   '709',
#   '719',
#   '207',
#   '175',
#   '249',
#   '260',
#   '183',
#   '641',
#   '362',
#   '409',
#   '429',
#   '518',
#   '449',
#   '379',
#   '359',
#   '347',
#   '342',
#   '340',
#   '846',
#   '317',
#   '321',
#   '325',
#   '357',
#   '241',
#   '462',
#   '475',
#   '528',
#   '480',
#   '514',
#   '437',
#   '451',
#   '486',
#   '199',
#   '64',
#   '153',
#   '90',
#   '224',
#   '814',
#   '283',
#   '297',
#   '848',
#   '831',
#   '281',
#   '273',
#   '916',
#   '902',
#   '921',
#   '934',
#   '268',
#   '805',
#   '833',
#   '804',
#   '903',
#   '932',
#   '151',
#   '147',
#   '174',
#   '195',
#   '222',
#   '741',
#   '756',
#   '390',
#   '737',
#   '726',
#   '358',
#   '421',
#   '445',
#   '587',
#   '464',
#   '557',
#   '549',
#   '624',
#   '631',
#   '572',
#   '563',
#   '552',
#   '522',
#   '614',
#   '715',
#   '714',
#   '144',
#   '661',
#   '634',
#   '730',
#   '338',
#   '349',
#   '351',
#   '353',
#   '246',
#   '521',
#   '488',
#   '478',
#   '555',
#   '556',
#   '907',
#   '282',
#   '292',
#   '935',
#   '263',
#   '933',
#   '926',
#   '922',
#   '191',
#   '732',
#   '158',
#   '727',
#   '721',
#   '284',
#   '759',
#   '858',
#   '576',
#   '578',
#   '541',
#   '623',
#   '332',
#   '423',
#   '176',
#   '181',
#   '668',
#   '364',
#   '374',
#   '350',
#   '373',
#   '381',
#   '355',
#   '531',
#   '483',
#   '553',
#   '909',
#   '930',
#   '915',
#   '911',
#   '931',
#   '815',
#   '194',
#   '754',
#   '749',
#   '618',
#   '92',
#   '628',
#   '472',
#   '806',
#   '837',
#   '290',
#   '296',
#   '857',
#   '735',
#   '746',
#   '649',
#   '635',
#   '636',
#   '367',
#   '360',
#   '376',
#   '854',
#   '288',
#   '747',
#   '738',
#   '768',
#   '757',
#   '467',
#   '562',
#   '617',
#   '627',
#   '361',
#   '368',
#   '370',
#   '479',
#   '852',
#   '745',
#   '771',
#   '766',
#   '773',
#   '755',
#   '758',
#   '577',
#   '619',
#   '720',
#   '377',
#   '356',
#   '842',
#   '453',
#   '803',
#   '937',
#   '762',
#   '739',
#   '774',
#   '760',
#   '366',
#   '375',
#   '844',
#   '734',
#   '778',
#   '197',
#   '369',
#   '929',
#   '830',
#   '856',
#   '764',
#   '744',
#   '684',
#   '908',
#   '765',
#   '686',
#   '683',
#   '840',
#   '783',
#   '784',
#   '750',
#   '770',
#   '495',
#   '835',
#   '685',
#   '682',
#   '853',
#   '753',
#   '781',
#   '775',
#   '657',
#   '776',
#   '498',
#   '824',
#   '847',
#   '378',
#   '645',
#   '681',
#   '841',
#   '782',
#   '388',
#   '674',
#   '675',
#   '845',
#   '851',
#   '785',
#   '372',
#   '673',
#   '482',
#   '836',
#   '788',
#   '189',
#   '829',
#   '843',
#   '800',
#   '629',
#   '630',
#   '676',
#   '761',
#   '655',
#   '794',
#   '790',
#   '689',
#   '492',
#   '748',
#   '795',
#   '796',
#   '799',
#   '196',
#   '696',
#   '849',
#   '798',
#   '791',
#   '494',
#   '897',
#   '855',
#   '802',
#   '779',
#   '190',
#   '688',
#   '658',
#   '660',
#   '687',
#   '697',
#   '827',
#   '777',
#   '743',
#   '651',
#   '647',
#   '695',
#   '698',
#   '693',
#   '694',
#   '665',
#   '828',
#   '906',
#   '653',
#   '867',
#   '667',
#   '680',
#   '763',
#   '780',
#   '671',
#   '690',
#   '883',
#   '792',
#   '192',
#   '669',
#   '977',
#   '944',
#   '691',
#   '917',
#   '825',
#   '895',
#   '672',
#   '650',
#   '884',
#   '821',
#   '881',
#   '885',
#   '882',
#   '393',
#   '394',
#   '666',
#   '656',
#   '399',
#   '386',
#   '391',
#   '652',
#   '862',
#   '864',
#   '863',
#   '860',
#   '659',
#   '868',
#   '859',
#   '861',
#   '397',
#   '786',
#   '787',
#   '826',
#   '877',
#   '834',
#   '876',
#   '678',
#   '898',
#   '878',
#   '767',
#   '872',
#   '880',
#   '874',
#   '380',
#   '677',
#   '870',
#   '871',
#   '865',
#   '866',
#   '879',
#   '797',
#   '875',
#   '389',
#   '850',
#   '920',
#   '387',
#   '392',
#   '904',
#   '949',
#   '395',
#   '396',
#   '822',
#   '886',
#   '873',
#   '670',
#   '899',
#   '692',
#   '978',
#   '887',
#   '939',
#   '905',
#   '927',
#   '894',
#   '679',
#   '936',
#   '919',
#   '896',
#   '188',
#   '923',
#   '888',
#   '938',
#   '654',
#   '943',
#   '940',
#   '942',
#   '398',
#   '769',
#   '966',
#   '945',
#   '889',
#   '941',
#   '947',
#   '946',
#   '918',
#   '869',
#   '976',
#   '979',
#   '567',
#   '948',
#   '953',
#   '789',
#   '980',
#   '823',
#   '974',
#   '496',
#   '965',
#   '975',
#   '952',
#   '961',
#   '500',
#   '950',
#   '382',
#   '568',
#   '385',
#   '793',
#   '497',
#   '893',
#   '566',
#   '569',
#   '493',
#   '384',
#   '383',
#   '580',
#   '579',
#   '700',
#   '581',
#   '583',
#   '582',
#   '574',
#   '891',
#   '892',
#   '299',
#   '300',
#   '962',
#   '699',
#   '956',
#   '951',
#   '957',
#   '958',
#   '955',
#   '954',
#   '964',
#   '959',
#   '963',
#   '969',
#   '968',
#   '970',
#   '960',
#   '973',
#   '972',
#   '971',
#   '967',
#   '596',
#   '588',
#   '589',
#   '981',
#   '984',
#   '985',
#   '986',
#   '989',
#   '987',
#   '988',
#   '990',
#   '499',
#   '590',
#   '591',
#   '592',
#   '593',
#   '890',
#   '997',
#   '992',
#   '998',
#   '991',
#   '996',
#   '995',
#   '999'],
#  'block_Final': [233,
#   130,
#   125,
#   115,
#   151,
#   148,
#   232,
#   135,
#   133,
#   164,
#   246,
#   170,
#   138,
#   146,
#   255,
#   238,
#   20,
#   13,
#   271,
#   273,
#   274,
#   25,
#   33,
#   35,
#   32,
#   31,
#   30,
#   337,
#   338,
#   339,
#   352,
#   353,
#   354,
#   379,
#   380,
#   381,
#   382,
#   389,
#   372,
#   370,
#   371,
#   360,
#   361,
#   406,
#   412,
#   415,
#   522,
#   539,
#   394,
#   405,
#   403,
#   515,
#   511,
#   508,
#   509,
#   486,
#   482,
#   551,
#   553,
#   554,
#   558,
#   562,
#   450,
#   448,
#   561,
#   557,
#   471,
#   459,
#   597,
#   491,
#   497,
#   500,
#   592,
#   590,
#   257,
#   260,
#   63,
#   59,
#   87,
#   90,
#   122,
#   147,
#   172,
#   5,
#   7,
#   272,
#   250,
#   24,
#   28,
#   349,
#   375,
#   363,
#   364,
#   414,
#   525,
#   538,
#   395,
#   493,
#   594,
#   591,
#   600,
#   57,
#   88,
#   263,
#   262,
#   335,
#   376,
#   367,
#   400,
#   398,
#   678,
#   494,
#   572,
#   574,
#   177,
#   3,
#   89,
#   200,
#   211,
#   223,
#   715,
#   726,
#   446,
#   447,
#   449,
#   111,
#   112,
#   123,
#   543,
#   532,
#   499,
#   134,
#   6,
#   9,
#   648,
#   256,
#   399,
#   19,
#   18,
#   29,
#   43,
#   848,
#   2,
#   347,
#   336,
#   351,
#   41,
#   476,
#   456,
#   472,
#   132,
#   127,
#   480,
#   481,
#   484,
#   485,
#   377,
#   489,
#   663,
#   566,
#   674,
#   444,
#   488,
#   556,
#   567,
#   56,
#   267,
#   289,
#   278,
#   344,
#   355,
#   477,
#   455,
#   770,
#   680,
#   687,
#   74,
#   671,
#   793,
#   748,
#   759,
#   771,
#   39,
#   37,
#   36,
#   38,
#   870,
#   571,
#   358,
#   452,
#   453,
#   463,
#   935,
#   913,
#   366,
#   492,
#   496,
#   669,
#   668,
#   675,
#   559,
#   560,
#   510,
#   73,
#   672,
#   564,
#   552,
#   555,
#   15,
#   0,
#   685,
#   682,
#   234,
#   14,
#   21,
#   946,
#   42,
#   44,
#   688,
#   156,
#   228,
#   235,
#   68,
#   69,
#   72,
#   86,
#   118,
#   165,
#   176,
#   333,
#   549,
#   52,
#   49,
#   51,
#   92,
#   143,
#   142,
#   161,
#   16,
#   71,
#   77,
#   117,
#   40,
#   94,
#   140,
#   27,
#   231,
#   136,
#   128,
#   48,
#   46,
#   47,
#   659,
#   334,
#   737,
#   22,
#   17,
#   443,
#   23,
#   67,
#   34,
#   10,
#   4,
#   8,
#   582,
#   550,
#   222,
#   100,
#   178,
#   300,
#   410,
#   11,
#   521,
#   421,
#   693,
#   615,
#   183,
#   191,
#   620,
#   881,
#   1,
#   619,
#   618,
#   585,
#   586,
#   596,
#   378,
#   454,
#   293,
#   295,
#   261,
#   249,
#   248,
#   252,
#   239,
#   237,
#   283,
#   451,
#   229,
#   230,
#   227,
#   368,
#   266,
#   461,
#   467,
#   664,
#   665,
#   673,
#   666,
#   695,
#   691,
#   667,
#   346,
#   240,
#   236,
#   225,
#   692,
#   302,
#   350,
#   348,
#   264,
#   679,
#   686,
#   114,
#   782,
#   388,
#   826,
#   968,
#   977,
#   604,
#   145,
#   626,
#   432,
#   322,
#   311,
#   78,
#   244,
#   243,
#   253,
#   345,
#   155,
#   61,
#   269,
#   281,
#   169,
#   226,
#   150,
#   153,
#   149,
#   159,
#   160,
#   175,
#   124,
#   121,
#   241,
#   342,
#   157,
#   258,
#   340,
#   75,
#   76,
#   79,
#   81,
#   95,
#   96,
#   97,
#   126,
#   129,
#   462,
#   457,
#   396,
#   433,
#   431,
#   429,
#   427,
#   417,
#   418,
#   474,
#   483,
#   426,
#   434,
#   423,
#   131,
#   386,
#   384,
#   385,
#   504,
#   501,
#   397,
#   373,
#   391,
#   487,
#   109,
#   116,
#   341,
#   409,
#   408,
#   773,
#   957,
#   12,
#   637,
#   924,
#   45,
#   815,
#   804,
#   466,
#   779,
#   401,
#   245,
#   80,
#   82,
#   859,
#   837,
#   704,
#   167,
#   186,
#   188,
#   907,
#   908,
#   790,
#   791,
#   780,
#   781,
#   206,
#   208,
#   194,
#   213,
#   215,
#   181,
#   896,
#   168,
#   141,
#   152,
#   190,
#   356,
#   64,
#   794,
#   792,
#   786,
#   783,
#   185,
#   184,
#   207,
#   192,
#   195,
#   217,
#   180,
#   895,
#   892,
#   171,
#   197,
#   911,
#   807,
#   813,
#   814,
#   66,
#   785,
#   784,
#   216,
#   369,
#   789,
#   210,
#   220,
#   894,
#   198,
#   199,
#   162,
#   55,
#   54,
#   891,
#   189,
#   119,
#   104,
#   113,
#   70,
#   662,
#   700,
#   707,
#   196,
#   717,
#   718,
#   697,
#   705,
#   201,
#   740,
#   144,
#   154,
#   173,
#   174,
#   254,
#   276,
#   523,
#   537,
#   393,
#   527,
#   512,
#   458,
#   470,
#   598,
#   573,
#   577,
#   62,
#   411,
#   516,
#   495,
#   563,
#   602,
#   660,
#   26,
#   362,
#   478,
#   465,
#   473,
#   578,
#   670,
#   681,
#   120,
#   84,
#   166,
#   179,
#   93,
#   595,
#   292,
#   343,
#   365,
#   464,
#   387,
#   310,
#   288,
#   275,
#   270,
#   268,
#   822,
#   242,
#   247,
#   251,
#   286,
#   158,
#   402,
#   416,
#   475,
#   422,
#   460,
#   374,
#   390,
#   428,
#   110,
#   593,
#   60,
#   882,
#   139,
#   787,
#   204,
#   219,
#   824,
#   806,
#   202,
#   193,
#   898,
#   883,
#   904,
#   918,
#   187,
#   777,
#   808,
#   776,
#   884,
#   916,
#   58,
#   53,
#   83,
#   106,
#   137,
#   706,
#   722,
#   323,
#   701,
#   689,
#   287,
#   357,
#   383,
#   540,
#   404,
#   507,
#   498,
#   576,
#   584,
#   524,
#   514,
#   502,
#   469,
#   565,
#   677,
#   676,
#   50,
#   617,
#   587,
#   694,
#   265,
#   277,
#   280,
#   282,
#   163,
#   468,
#   430,
#   419,
#   505,
#   506,
#   888,
#   203,
#   214,
#   919,
#   182,
#   917,
#   909,
#   905,
#   102,
#   696,
#   65,
#   690,
#   684,
#   205,
#   725,
#   835,
#   528,
#   530,
#   490,
#   575,
#   259,
#   359,
#   85,
#   91,
#   624,
#   294,
#   305,
#   279,
#   304,
#   313,
#   284,
#   479,
#   425,
#   503,
#   890,
#   914,
#   897,
#   893,
#   915,
#   788,
#   105,
#   720,
#   714,
#   569,
#   902,
#   580,
#   413,
#   778,
#   812,
#   212,
#   218,
#   834,
#   699,
#   711,
#   603,
#   588,
#   589,
#   297,
#   290,
#   307,
#   831,
#   209,
#   712,
#   702,
#   735,
#   723,
#   407,
#   513,
#   568,
#   579,
#   291,
#   298,
#   301,
#   420,
#   829,
#   710,
#   739,
#   733,
#   741,
#   721,
#   724,
#   529,
#   570,
#   683,
#   308,
#   285,
#   818,
#   392,
#   775,
#   921,
#   729,
#   703,
#   742,
#   727,
#   296,
#   306,
#   820,
#   698,
#   746,
#   108,
#   299,
#   912,
#   805,
#   833,
#   731,
#   709,
#   642,
#   889,
#   732,
#   644,
#   641,
#   816,
#   752,
#   753,
#   716,
#   738,
#   438,
#   810,
#   643,
#   640,
#   830,
#   719,
#   750,
#   743,
#   612,
#   744,
#   441,
#   798,
#   823,
#   309,
#   599,
#   639,
#   817,
#   751,
#   320,
#   631,
#   632,
#   821,
#   828,
#   754,
#   303,
#   630,
#   424,
#   811,
#   757,
#   99,
#   803,
#   819,
#   772,
#   581,
#   583,
#   633,
#   728,
#   610,
#   764,
#   760,
#   647,
#   435,
#   713,
#   765,
#   766,
#   769,
#   107,
#   655,
#   825,
#   768,
#   761,
#   437,
#   878,
#   832,
#   774,
#   747,
#   101,
#   646,
#   613,
#   616,
#   645,
#   656,
#   801,
#   745,
#   708,
#   606,
#   601,
#   654,
#   657,
#   652,
#   653,
#   621,
#   802,
#   887,
#   608,
#   845,
#   623,
#   638,
#   730,
#   749,
#   628,
#   649,
#   863,
#   762,
#   103,
#   625,
#   965,
#   929,
#   650,
#   899,
#   799,
#   876,
#   629,
#   605,
#   864,
#   795,
#   861,
#   865,
#   862,
#   326,
#   327,
#   622,
#   611,
#   332,
#   318,
#   324,
#   607,
#   840,
#   842,
#   841,
#   838,
#   614,
#   846,
#   836,
#   839,
#   330,
#   755,
#   756,
#   800,
#   856,
#   809,
#   855,
#   635,
#   879,
#   857,
#   734,
#   851,
#   860,
#   853,
#   312,
#   634,
#   849,
#   850,
#   843,
#   844,
#   858,
#   767,
#   854,
#   321,
#   827,
#   903,
#   319,
#   325,
#   885,
#   934,
#   328,
#   329,
#   796,
#   866,
#   852,
#   627,
#   880,
#   651,
#   966,
#   867,
#   923,
#   886,
#   910,
#   875,
#   636,
#   920,
#   901,
#   877,
#   98,
#   906,
#   868,
#   922,
#   609,
#   928,
#   925,
#   927,
#   331,
#   736,
#   953,
#   930,
#   869,
#   926,
#   932,
#   931,
#   900,
#   847,
#   964,
#   967,
#   518,
#   933,
#   939,
#   758,
#   969,
#   797,
#   962,
#   439,
#   952,
#   963,
#   938,
#   948,
#   445,
#   936,
#   314,
#   519,
#   317,
#   763,
#   440,
#   874,
#   517,
#   520,
#   436,
#   316,
#   315,
#   533,
#   531,
#   661,
#   534,
#   536,
#   535,
#   526,
#   872,
#   873,
#   221,
#   224,
#   949,
#   658,
#   942,
#   937,
#   943,
#   944,
#   941,
#   940,
#   951,
#   945,
#   950,
#   956,
#   955,
#   958,
#   947,
#   961,
#   960,
#   959,
#   954,
#   548,
#   541,
#   542,
#   970,
#   971,
#   972,
#   973,
#   976,
#   974,
#   975,
#   978,
#   442,
#   544,
#   545,
#   546,
#   547,
#   871,
#   983,
#   980,
#   984,
#   979,
#   982,
#   981,
#   985],
#  'street_name_initial': [13,
#   16,
#   17,
#   14,
#   18,
#   20,
#   19,
#   21,
#   15,
#   45,
#   42,
#   50,
#   340,
#   39,
#   47,
#   115,
#   114,
#   38,
#   49,
#   48,
#   41,
#   43,
#   36,
#   37,
#   35,
#   40,
#   116,
#   437,
#   425,
#   70,
#   86,
#   84,
#   71,
#   68,
#   67,
#   200,
#   65,
#   75,
#   66,
#   448,
#   487,
#   52,
#   488,
#   166,
#   490,
#   236,
#   199,
#   228,
#   90,
#   198,
#   92,
#   489,
#   178,
#   292,
#   385,
#   226,
#   197,
#   241,
#   248,
#   235,
#   294,
#   335,
#   492,
#   299,
#   298,
#   175,
#   382,
#   181,
#   242,
#   345,
#   424,
#   397,
#   505,
#   510,
#   380,
#   97,
#   393,
#   392,
#   30,
#   438,
#   509,
#   484,
#   486,
#   143,
#   512,
#   142,
#   145,
#   144,
#   141,
#   513,
#   151,
#   152,
#   149,
#   99,
#   146,
#   150,
#   139,
#   322,
#   246,
#   192,
#   176,
#   434,
#   5,
#   189,
#   163,
#   366,
#   196,
#   31,
#   238,
#   191,
#   177,
#   208,
#   210,
#   205,
#   218,
#   206,
#   318,
#   216,
#   212,
#   217,
#   483,
#   255,
#   260,
#   256,
#   257,
#   258,
#   259,
#   347,
#   579,
#   201,
#   227,
#   61,
#   60,
#   62,
#   271,
#   268,
#   261,
#   269,
#   233,
#   441,
#   342,
#   186,
#   33,
#   514,
#   504,
#   51,
#   517,
#   320,
#   285,
#   188,
#   167,
#   346,
#   291,
#   232,
#   338,
#   501,
#   247,
#   290,
#   2,
#   300,
#   162,
#   324,
#   325,
#   327,
#   100,
#   102,
#   481,
#   101,
#   170,
#   323,
#   194,
#   169,
#   442,
#   334,
#   203,
#   202,
#   204,
#   168,
#   398,
#   319,
#   420,
#   415,
#   417,
#   418,
#   458,
#   460,
#   480,
#   475,
#   450,
#   461,
#   459,
#   462,
#   463,
#   467,
#   476,
#   477,
#   451,
#   310,
#   317,
#   308,
#   314,
#   312,
#   316,
#   497,
#   313,
#   496,
#   498,
#   370,
#   368,
#   503,
#   254,
#   330,
#   329,
#   332,
#   328,
#   526,
#   545,
#   544,
#   563,
#   557,
#   574,
#   564,
#   566,
#   567,
#   555,
#   113,
#   583,
#   303,
#   439,
#   339,
#   494,
#   289,
#   363,
#   502,
#   433,
#   581,
#   482,
#   195,
#   59,
#   516,
#   103,
#   468,
#   315,
#   295,
#   558,
#   560,
#   573,
#   76,
#   426,
#   495,
#   394,
#   440,
#   305,
#   98,
#   381,
#   416,
#   369,
#   518,
#   556,
#   321,
#   341,
#   245,
#   234,
#   117,
#   112,
#   343,
#   6,
#   96,
#   77,
#   3,
#   119,
#   435,
#   207,
#   213,
#   402,
#   429,
#   78,
#   88,
#   306,
#   251,
#   547,
#   436,
#   80,
#   165,
#   367,
#   209,
#   383,
#   572,
#   54,
#   243,
#   470,
#   469,
#   55,
#   239,
#   554,
#   253,
#   171,
#   387,
#   297,
#   384,
#   302,
#   223,
#   493,
#   331,
#   575,
#   79,
#   82,
#   81,
#   282,
#   281,
#   187,
#   333,
#   431,
#   559,
#   421,
#   553,
#   32,
#   278,
#   344,
#   211,
#   354,
#   364,
#   365,
#   311,
#   53,
#   352,
#   57,
#   283,
#   353,
#   561,
#   56,
#   428,
#   478,
#   91,
#   284,
#   179,
#   549,
#   127,
#   358,
#   222,
#   111,
#   500,
#   215,
#   293,
#   453,
#   471,
#   430,
#   519,
#   304,
#   550,
#   423,
#   419,
#   64,
#   395,
#   122,
#   454,
#   270,
#   578,
#   414,
#   357,
#   190,
#   121,
#   296,
#   351,
#   356,
#   405,
#   221,
#   277,
#   276,
#   359,
#   464,
#   123,
#   129,
#   250,
#   455,
#   465,
#   85,
#   263,
#   452,
#   551,
#   133,
#   350,
#   562,
#   120,
#   546,
#   89,
#   355,
#   174,
#   58,
#   515,
#   548,
#   361,
#   279,
#   348,
#   362,
#   349,
#   134,
#   140,
#   131,
#   360,
#   130,
#   23,
#   237,
#   137,
#   521,
#   532,
#   135,
#   474,
#   507,
#   280,
#   443,
#   24,
#   466,
#   577,
#   520,
#   132,
#   22,
#   523,
#   580,
#   128,
#   136,
#   386,
#   286,
#   447,
#   432,
#   529,
#   537,
#   473,
#   530,
#   422,
#   229,
#   72,
#   224,
#   522,
#   524,
#   161,
#   307,
#   539,
#   138,
#   73,
#   249,
#   525,
#   535,
#   118,
#   74,
#   214,
#   264,
#   542,
#   124,
#   499,
#   272,
#   527,
#   225,
#   126,
#   399,
#   106,
#   400,
#   403,
#   160,
#   390,
#   536,
#   401,
#   534,
#   533,
#   391,
#   156,
#   389,
#   413,
#   275,
#   388,
#   531,
#   155,
#   528,
#   158,
#   540,
#   219,
#   274,
#   538,
#   565,
#   0,
#   159,
#   46,
#   582,
#   1,
#   409,
#   25,
#   28,
#   63,
#   273,
#   10,
#   105,
#   154,
#   148,
#   336,
#   511,
#   408,
#   262,
#   9,
#   412,
#   173,
#   8,
#   396,
#   180,
#   374,
#   172,
#   11,
#   109,
#   244,
#   182,
#   267,
#   147,
#   375,
#   301,
#   371,
#   230,
#   93,
#   541,
#   83,
#   231,
#   372,
#   266,
#   404,
#   184,
#   95,
#   183,
#   252,
#   576,
#   157,
#   326,
#   153,
#   377,
#   34,
#   373,
#   406,
#   110,
#   376,
#   410,
#   456,
#   193,
#   427,
#   569,
#   491,
#   240,
#   309,
#   378,
#   411,
#   94,
#   379,
#   568,
#   485,
#   337,
#   506,
#   445,
#   407,
#   552,
#   7,
#   12,
#   457,
#   571,
#   508,
#   449,
#   44,
#   29,
#   164,
#   185,
#   220,
#   479,
#   446,
#   125,
#   287,
#   265,
#   288,
#   4,
#   104,
#   444,
#   107,
#   26,
#   27,
#   69,
#   87,
#   108,
#   543,
#   472,
#   570],
#  'street_name_Final': [13,
#   16,
#   17,
#   14,
#   18,
#   20,
#   19,
#   21,
#   15,
#   45,
#   42,
#   50,
#   340,
#   39,
#   47,
#   115,
#   114,
#   38,
#   49,
#   48,
#   41,
#   43,
#   36,
#   37,
#   35,
#   40,
#   116,
#   437,
#   425,
#   70,
#   86,
#   84,
#   71,
#   68,
#   67,
#   200,
#   65,
#   75,
#   66,
#   448,
#   487,
#   52,
#   488,
#   166,
#   490,
#   236,
#   199,
#   228,
#   90,
#   198,
#   92,
#   489,
#   178,
#   292,
#   385,
#   226,
#   197,
#   241,
#   248,
#   235,
#   294,
#   335,
#   492,
#   299,
#   298,
#   175,
#   382,
#   181,
#   242,
#   345,
#   424,
#   397,
#   505,
#   510,
#   380,
#   97,
#   393,
#   392,
#   30,
#   438,
#   509,
#   484,
#   486,
#   143,
#   512,
#   142,
#   145,
#   144,
#   141,
#   513,
#   151,
#   152,
#   149,
#   99,
#   146,
#   150,
#   139,
#   322,
#   246,
#   192,
#   176,
#   434,
#   5,
#   189,
#   163,
#   366,
#   196,
#   31,
#   238,
#   191,
#   177,
#   208,
#   210,
#   205,
#   218,
#   206,
#   318,
#   216,
#   212,
#   217,
#   483,
#   255,
#   260,
#   256,
#   257,
#   258,
#   259,
#   347,
#   579,
#   201,
#   227,
#   61,
#   60,
#   62,
#   271,
#   268,
#   261,
#   269,
#   233,
#   441,
#   342,
#   186,
#   33,
#   514,
#   504,
#   51,
#   517,
#   320,
#   285,
#   188,
#   167,
#   346,
#   291,
#   232,
#   338,
#   501,
#   247,
#   290,
#   2,
#   300,
#   162,
#   324,
#   325,
#   327,
#   100,
#   102,
#   481,
#   101,
#   170,
#   323,
#   194,
#   169,
#   442,
#   334,
#   203,
#   202,
#   204,
#   168,
#   398,
#   319,
#   420,
#   415,
#   417,
#   418,
#   458,
#   460,
#   480,
#   475,
#   450,
#   461,
#   459,
#   462,
#   463,
#   467,
#   476,
#   477,
#   451,
#   310,
#   317,
#   308,
#   314,
#   312,
#   316,
#   497,
#   313,
#   496,
#   498,
#   370,
#   368,
#   503,
#   254,
#   330,
#   329,
#   332,
#   328,
#   526,
#   545,
#   544,
#   563,
#   557,
#   574,
#   564,
#   566,
#   567,
#   555,
#   113,
#   583,
#   303,
#   439,
#   339,
#   494,
#   289,
#   363,
#   502,
#   433,
#   581,
#   482,
#   195,
#   59,
#   516,
#   103,
#   468,
#   315,
#   295,
#   558,
#   560,
#   573,
#   76,
#   426,
#   495,
#   394,
#   440,
#   305,
#   98,
#   381,
#   416,
#   369,
#   518,
#   556,
#   321,
#   341,
#   245,
#   234,
#   117,
#   112,
#   343,
#   6,
#   96,
#   77,
#   3,
#   119,
#   435,
#   207,
#   213,
#   402,
#   429,
#   78,
#   88,
#   306,
#   251,
#   547,
#   436,
#   80,
#   165,
#   367,
#   209,
#   383,
#   572,
#   54,
#   243,
#   470,
#   469,
#   55,
#   239,
#   554,
#   253,
#   171,
#   387,
#   297,
#   384,
#   302,
#   223,
#   493,
#   331,
#   575,
#   79,
#   82,
#   81,
#   282,
#   281,
#   187,
#   333,
#   431,
#   559,
#   421,
#   553,
#   32,
#   278,
#   344,
#   211,
#   354,
#   364,
#   365,
#   311,
#   53,
#   352,
#   57,
#   283,
#   353,
#   561,
#   56,
#   428,
#   478,
#   91,
#   284,
#   179,
#   549,
#   127,
#   358,
#   222,
#   111,
#   500,
#   215,
#   293,
#   453,
#   471,
#   430,
#   519,
#   304,
#   550,
#   423,
#   419,
#   64,
#   395,
#   122,
#   454,
#   270,
#   578,
#   414,
#   357,
#   190,
#   121,
#   296,
#   351,
#   356,
#   405,
#   221,
#   277,
#   276,
#   359,
#   464,
#   123,
#   129,
#   250,
#   455,
#   465,
#   85,
#   263,
#   452,
#   551,
#   133,
#   350,
#   562,
#   120,
#   546,
#   89,
#   355,
#   174,
#   58,
#   515,
#   548,
#   361,
#   279,
#   348,
#   362,
#   349,
#   134,
#   140,
#   131,
#   360,
#   130,
#   23,
#   237,
#   137,
#   521,
#   532,
#   135,
#   474,
#   507,
#   280,
#   443,
#   24,
#   466,
#   577,
#   520,
#   132,
#   22,
#   523,
#   580,
#   128,
#   136,
#   386,
#   286,
#   447,
#   432,
#   529,
#   537,
#   473,
#   530,
#   422,
#   229,
#   72,
#   224,
#   522,
#   524,
#   161,
#   307,
#   539,
#   138,
#   73,
#   249,
#   525,
#   535,
#   118,
#   74,
#   214,
#   264,
#   542,
#   124,
#   499,
#   272,
#   527,
#   225,
#   126,
#   399,
#   106,
#   400,
#   403,
#   160,
#   390,
#   536,
#   401,
#   534,
#   533,
#   391,
#   156,
#   389,
#   413,
#   275,
#   388,
#   531,
#   155,
#   528,
#   158,
#   540,
#   219,
#   274,
#   538,
#   565,
#   0,
#   159,
#   46,
#   582,
#   1,
#   409,
#   25,
#   28,
#   63,
#   273,
#   10,
#   105,
#   154,
#   148,
#   336,
#   511,
#   408,
#   262,
#   9,
#   412,
#   173,
#   8,
#   396,
#   180,
#   374,
#   172,
#   11,
#   109,
#   244,
#   182,
#   267,
#   147,
#   375,
#   301,
#   371,
#   230,
#   93,
#   541,
#   83,
#   231,
#   372,
#   266,
#   404,
#   184,
#   95,
#   183,
#   252,
#   576,
#   157,
#   326,
#   153,
#   377,
#   34,
#   373,
#   406,
#   110,
#   376,
#   410,
#   456,
#   193,
#   427,
#   569,
#   491,
#   240,
#   309,
#   378,
#   411,
#   94,
#   379,
#   568,
#   485,
#   337,
#   506,
#   445,
#   407,
#   552,
#   7,
#   12,
#   457,
#   571,
#   508,
#   449,
#   44,
#   29,
#   164,
#   185,
#   220,
#   479,
#   446,
#   125,
#   287,
#   265,
#   288,
#   4,
#   104,
#   444,
#   107,
#   26,
#   27,
#   69,
#   87,
#   108,
#   543,
#   472,
#   570],
#  'flat_model_initial': [7,
#   20,
#   12,
#   27,
#   26,
#   13,
#   3,
#   11,
#   30,
#   0,
#   8,
#   14,
#   22,
#   9,
#   21,
#   16,
#   29,
#   5,
#   28,
#   17,
#   15,
#   19,
#   4,
#   23,
#   31,
#   10,
#   25,
#   1,
#   18,
#   32,
#   33,
#   6,
#   24,
#   2],
#  'flat_model_Final': [7,
#   20,
#   12,
#   27,
#   26,
#   13,
#   3,
#   11,
#   30,
#   0,
#   8,
#   14,
#   22,
#   9,
#   21,
#   16,
#   29,
#   5,
#   28,
#   17,
#   15,
#   19,
#   4,
#   23,
#   31,
#   10,
#   25,
#   1,
#   18,
#   32,
#   33,
#   6,
#   24,
#   2]}

# %%
with open('Cat_Columns_Encoded_value.json', 'w') as file:
    json.dump(unique_dist, file , indent = 4)
